# %%
import os, pickle, glob, ast, requests, json
import pandas as pd
import numpy as np
from tqdm import tqdm
from PIL import Image
import matplotlib.pyplot as plt
import os

# %%
final_data = pd.read_csv('gmdb_phenogpt2.csv', sep = '\t')

# %%
image_id = 16673
# Construct the full image path
img_path = f"/mnt/isilon/wang_lab/quan/projects/MedicalDBs/GMDB/gmdb_crops_v1.0.9/gmdb_crops/{image_id}_aligned.jpg"
print(final_data.loc[final_data['filename'] == f"{image_id}.png",'phenotypes_vision'].values[0])
# Open and display the image
image = Image.open(img_path)
plt.imshow(image)
plt.axis("off")  # Hide axes
plt.show()
# Out:
# {'triangular face': 'HP:0000325', 'long philtrum': 'HP:0000343', 'macrotia': 'HP:0000400'}

# %%
image_id = 169
# Construct the full image path
img_path = f"/mnt/isilon/wang_lab/quan/projects/MedicalDBs/GMDB/gmdb_crops_v1.0.9/gmdb_crops/{image_id}_aligned.jpg"
print(final_data.loc[final_data['filename'].str.contains(f"{image_id}."),'phenotypes_vision'].values[0])
# Open and display the image
image = Image.open(img_path)
plt.imshow(image)
plt.axis("off")  # Hide axes
plt.show()
# Out:
# {'thin upper lip vermilion': 'HP:0000219', 'hypertelorism': 'HP:0000316', 'wide nasal bridge': 'HP:0000431', 'broad nasal tip': 'HP:0000455', 'upslanted palpebral fissure': 'HP:0000582', 'long palpebral fissure': 'HP:0000637', 'downturned corners of mouth': 'HP:0002714', 'short nose': 'HP:0003196', 'moderate sensorineural hearing impairment': 'HP:0008504'}

# %%
image_id = 16673
# Construct the full image path
img_path = f"/mnt/isilon/wang_lab/quan/projects/MedicalDBs/GMDB/gmdb_crops_v1.0.9/gmdb_crops/{image_id}_aligned.jpg"
print(final_data.loc[final_data['filename'] == f"{image_id}.png",'phenotypes_vision'].values[0])
# Open and display the image
image = Image.open(img_path)
plt.imshow(image)
plt.axis("off")  # Hide axes
plt.show()
